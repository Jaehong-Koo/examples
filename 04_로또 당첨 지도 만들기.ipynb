# %%
# pip install folium
import requests # http 요청을 주고 받을 수 있는 라이브러리, 카카오 API와 연관이 많습니다.
import json # json 형태를 다루기 위함
import pandas as pd # 판다스 형태를 다루기 위함
import folium # 지도와 관련된 라이브러리
from folium.plugins import MarkerCluster # 군집화할 때 필요합니다.

# %%
    ##### 로또 지도 만들기(로또 명당 지도 색깔로 차이 보여주기)
    ##### 기획재정부 로또 데이터(2019~2020), 상호명, 지역구, 당첨횟수 존재
    ##### 카카오지도 api활용 검색어(지역구 + 상호명)로 위도/경도 값 가져오기 (ex) 인천 중구 gs25 -> 33.xx, 120.xx
    ##### folium 라이브러리에 위도 경도 값 넣어줄 것
    ##### circleMarker 활용 지도에 표시

# %%
# csv 파일 열어서 shop_df 이름의 데이터프레임 형태로 지정
shop_df = pd.read_csv('Lotto_data.csv', encoding='cp949')

# %%
shop_df
# Out:
#       순번           상호      지역  1등 자동 당첨 건수
# 0      1      일등복권편의점  대구 달서구            5
# 1      2        오케이상사  서울 서초구            3
# 2      3       세진전자통신   대구 서구            2
# 3      4        라이프마트   인천 중구            2
# 4      5           스파  서울 노원구            2
# ..   ...          ...     ...          ...
# 325  326  GS25(수원행복점)  경기 수원시            1
# 326  327    CU(강릉내곡점)  강원 강릉시            1
# 327  328  GS25(청주수곡점)  충북 청주시            1
# 328  329  GS25(천안시민점)  충남 천안시            1
# 329  330  GS25(양산혜인점)  경남 양산시            1
#
# [330 rows x 4 columns]

# %%
shop_df['위도'] = 0

# %%
shop_df['경도'] = 0

# %%
shop_df = shop_df[['상호', '지역', '1등 자동 당첨 건수', '위도', '경도']] # 컬럼 정리

# %%
shop_df
# Out:
#               상호      지역  1등 자동 당첨 건수  위도  경도
# 0        일등복권편의점  대구 달서구            5   0   0
# 1          오케이상사  서울 서초구            3   0   0
# 2         세진전자통신   대구 서구            2   0   0
# 3          라이프마트   인천 중구            2   0   0
# 4             스파  서울 노원구            2   0   0
# ..           ...     ...          ...  ..  ..
# 325  GS25(수원행복점)  경기 수원시            1   0   0
# 326    CU(강릉내곡점)  강원 강릉시            1   0   0
# 327  GS25(청주수곡점)  충북 청주시            1   0   0
# 328  GS25(천안시민점)  충남 천안시            1   0   0
# 329  GS25(양산혜인점)  경남 양산시            1   0   0
#
# [330 rows x 5 columns]

# %%
shop_df['지역'][0]
# Out:
# '대구 달서구'

# %%
shop_df['상호'][0]
# Out:
# '일등복권편의점'

# %%
kakao_url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query=대구 달서구 일등복권편의점'

# %%
kakao_url
# Out:
# 'https://dapi.kakao.com/v2/local/search/keyword.json?query=대구 달서구 일등복권편의점'

# %%
requests.get(kakao_url)
# Out:
# <Response [401]>

# %%
kakao_url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(shop_df['지역'][0]+" "+shop_df['상호'][0])

# %%
kakao_url
# Out:
# 'https://dapi.kakao.com/v2/local/search/keyword.json?query=대구 달서구 일등복권편의점'

# %%
kakao_url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query=대구 달서구 일등복권편의점'
api_key = {"Authorization": "KakaoAK 1439f9abe991202819f1c10793070959"}

# %%
requests.get(kakao_url, headers=api_key)
# Out:
# <Response [200]>

# %%
requests.get(kakao_url, headers=api_key).json()
# Out:
# {'documents': [{'address_name': '대구 달서구 본리동 2-16',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '가정,생활 > 취미 > 복권',
#    'distance': '',
#    'id': '15726733',
#    'phone': '053-522-6808',
#    'place_name': '일등복권편의점',
#    'place_url': 'http://place.map.kakao.com/15726733',
#    'road_address_name': '대구 달서구 대명천로 220',
#    'x': '128.53614960474',
#    'y': '35.8421935317643'}],
#  'meta': {'is_end': True,
#   'pageable_count': 1,
#   'same_name': {'keyword': '일등복권편의점',
#    'region': [],
#    'selected_region': '대구 달서구'},
#   'total_count': 1}}

# %%
shop_place = requests.get(kakao_url, headers=headers).json()

# %%
shop_place
# Out:
# {'documents': [{'address_name': '대구 달서구 본리동 2-16',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '가정,생활 > 취미 > 복권',
#    'distance': '',
#    'id': '15726733',
#    'phone': '053-522-6808',
#    'place_name': '일등복권편의점',
#    'place_url': 'http://place.map.kakao.com/15726733',
#    'road_address_name': '대구 달서구 대명천로 220',
#    'x': '128.53614960474',
#    'y': '35.8421935317643'}],
#  'meta': {'is_end': True,
#   'pageable_count': 1,
#   'same_name': {'keyword': '일등복권편의점',
#    'region': [],
#    'selected_region': '대구 달서구'},
#   'total_count': 1}}

# %%
shop_place['documents']
# Out:
# [{'address_name': '대구 달서구 본리동 2-16',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '가정,생활 > 취미 > 복권',
#   'distance': '',
#   'id': '15726733',
#   'phone': '053-522-6808',
#   'place_name': '일등복권편의점',
#   'place_url': 'http://place.map.kakao.com/15726733',
#   'road_address_name': '대구 달서구 대명천로 220',
#   'x': '128.53614960474',
#   'y': '35.8421935317643'}]

# %%
shop_place['documents'][0]
# Out:
# {'address_name': '대구 달서구 본리동 2-16',
#  'category_group_code': '',
#  'category_group_name': '',
#  'category_name': '가정,생활 > 취미 > 복권',
#  'distance': '',
#  'id': '15726733',
#  'phone': '053-522-6808',
#  'place_name': '일등복권편의점',
#  'place_url': 'http://place.map.kakao.com/15726733',
#  'road_address_name': '대구 달서구 대명천로 220',
#  'x': '128.53614960474',
#  'y': '35.8421935317643'}

# %%
shop_place['documents'][0]['x']
# Out:
# '128.53614960474'

# %%
shop_place['documents'][0]['y']
# Out:
# '35.8421935317643'

# %%
# 위도, 경도를 포함한 정보를 뽑아주는 함수 만들기
def address_finder(cnt):
    searching = shop_df['지역'][cnt] + " " + shop_df['상호'][cnt] # 검색어 조합을 지역구 + 상호명으로 만들어 줄 것
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching) # 카카오 api에 입력, foramt화
    api_key = {"Authorization": "KakaoAK 1439f9abe991202819f1c10793070959"} # api키 입력
    place_result = requests.get(url, headers = api_key).json()['documents'][0]
    
    y = place_result['y'] # y 값은 y(위도)로 지정
    x = place_result['x'] # x 값은 x(경도)로 지정
    
    name = shop_df['상호'][cnt] # 상호명을 shop_df에서 가져오기
    count = shop_df['1등 자동 당첨 건수'][cnt] # 1등 자동 당첨 건수를 shop_df에서 가져오기
    
    df = pd.DataFrame({'상호' : name, '1등 자동 당첨 건수' : count, '위도' : y, '경도' : x}, index = [0]) # 데이터프레임화
    
    return df

# %%
address_finder(5)
# Out:
#        상호  1등 자동 당첨 건수                위도                  경도
# 0  노다지복권방            2  37.4432444008982  126.66470929195675

# %%
korea_center = folium.Map(location = [36.3505, 127.3848], zoom_start=8)

# %%
korea_center
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
korea_center = folium.Map(location = [36.3505, 127.3848], zoom_start=8)
folium.Marker(
    location = [36.3721, 127.3604], 
    popup = 'KAIST', 
    icon = folium.Icon(color = 'blue', icon = 'star')
).add_to(korea_center)

# %%
korea_center
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
korea_center = folium.Map(location = [36.3505, 127.3848], zoom_start=8)
folium.CircleMarker(
    [36.0139, 129.3232],
    radius = 10,
    color = '#ff0000',
    fill_color = '#ff0000',
    popup = 'POSTECH').add_to(korea_center)

# %%
korea_center
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
final_map_korea = folium.Map(location = [36.3505, 127.3848], zoom_start=8) # 줌 8배율의 대전시청 기준 우리나라 지도 불러오기

for cnt in range(0, len(shop_df)):
    try:
        folium.CircleMarker([address_finder(cnt)['위도'][0], address_finder(cnt)['경도'][0]],
                            radius = int(address_finder(cnt)['1등 자동 당첨 건수'][0])*4, # 당첨 건수만큼 비례해서 크게 만들기(곱하기 4)
                            popup = address_finder(cnt)['상호'][0], # 팝업메세지 내용
                            color = '#FF0000', # 원 선의 색상 빨간색 지정
                            fill_color = '#FF0000' # 원 안의 색상 빨간색 지정
                           ).add_to(final_map_korea) # 앞에서 만든 final_map_korea에 추가하기
    except:
        pass

# %%
final_map_korea
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
address_finder(0)
# Out:
#         상호  1등 자동 당첨 건수                위도               경도
# 0  일등복권편의점            5  35.8421935317643  128.53614960474

# %%
address_finder(0)['위도']
# Out:
# 0    35.8421935317643
# Name: 위도, dtype: object

# %%
marker_cluster = MarkerCluster().add_to(final_map_korea)
for cnt in range(0, 20): # 값이 329번째까지 있으므로 거기까지 불러오기
    try:
        folium.Marker([address_finder(cnt)['위도'][0], address_finder(cnt)['경도'][0]], icon = folium.Icon(color="red")).add_to(marker_cluster)
        
        folium.CircleMarker([address_finder(cnt)['위도'][0], address_finder(cnt)['경도'][0]], # 위도, 경도 값 위의 함수 활용 넣어줄 것
                            radius = int(address_finder(cnt)['당첨횟수'][0])*4, # 당첨횟수만큼 크게 만들어주기(곱하기 4)
                            popup = address_finder(cnt)['상호'][0] +": "+str(address_finder(cnt)['당첨횟수'][0])+"회" , # 팝업할때 상호명
                            color = '#FF0000', # 색상은 빨간색으로
                            fill_color = '#FF0000').add_to(final_map_korea) # 맵에 넣어주기
    except:
        pass

# %%
final_map_korea
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
final_map_korea.save('Lotto_map.html')
